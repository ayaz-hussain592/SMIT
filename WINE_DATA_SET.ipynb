# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("winequalitydata.csv")

# %%
X = data[list(data.columns)[:-1]]
Y = data[["quality"]]

# %%
Y
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
X_train , X_test , y_train, y_test = train_test_split(X,Y)

# %%
regressor = LinearRegression()

# %%
plt.scatter(data["alcohol"], data["quality"])
plt.xlabel("Alcohol")
plt.ylabel('Quality')
plt.title("Alcohol Against Quality")
plt.show()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predictions = regressor.predict(X_test)

# %%
print("R_squared",regressor.score(X_test,y_test))
# Out:
# R_squared 0.3478207621100171

# %%
from sklearn.model_selection import cross_val_score,cross_val_predict

# %%
score = cross_val_score(regressor,X,Y)

# %%
score.mean()
# Out:
# 0.2900416288421962

# %%
y_test = y_test.quality
y_test
# Out:
# 0      5
# 1      5
# 2      5
# 3      6
# 4      5
#       ..
# 395    5
# 396    6
# 397    5
# 398    5
# 399    5
# Name: quality, Length: 400, dtype: int64

# %%
predictions = cross_val_predict(regressor,X_test,y_test)

# %%
for i,p in enumerate(predictions):
    print(f"Actual {y_test.iloc[i]} >>>>Predicted is {p}")
# Out:
# Actual 5 >>>>Predicted is5.7209481779007945
# Actual 5 >>>>Predicted is5.375323282580851
# Actual 5 >>>>Predicted is5.341453696606884
# Actual 6 >>>>Predicted is5.213529250252812
# Actual 5 >>>>Predicted is5.99946884818344
# Actual 6 >>>>Predicted is6.4241294005651355
# Actual 6 >>>>Predicted is5.18488584301555
# Actual 7 >>>>Predicted is6.063989785348504
# Actual 5 >>>>Predicted is5.310304815270868
# Actual 6 >>>>Predicted is5.8789047639185625
# Actual 5 >>>>Predicted is5.666812961779492
# Actual 5 >>>>Predicted is5.07072260106748
# Actual 6 >>>>Predicted is5.473051335545698
# Actual 5 >>>>Predicted is5.288874644976737
# Actual 6 >>>>Predicted is6.046513006076104
# Actual 5 >>>>Predicted is5.667298007522156
# Actual 6 >>>>Predicted is6.394541528687341
# Actual 5 >>>>Predicted is5.132755010988177
# Actual 5 >>>>Predicted is5.2508867179142555
# Actual 5 >>>>Predicted is5.334338642535698
# Actual 5 >>>>Predicted is4.914304220138455
# Actual 7 >>>>Predicted is5.545423596223301
# ...

# %%
plt.scatter(y_test,predictions)
plt.ylabel("Predictions")
plt.xlabel('Quality')
plt.title("Predictions Against Quality")
plt.show()
